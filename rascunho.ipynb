# %%
import numpy as np
from pynfft.nfft import NFFT

def funcao_nfft(x, f_hat):
    N = [16, 16]  # Domínio da frequência (2D)
    M = len(x)        # Número de amostras
    plan = NFFT(N, M)
    plan.x = x
    plan.precompute()  # Pré-computação

    plan.f_hat = f_hat
    # Transformada direta: f_hat -> f
    f = plan.trafo()

    # Transformada adjunta: f -> f_hat
    plan.f = f
    return f

# %%
# Inicializa o plano NFFT
N = [16, 16]  # Domínio da frequência (2D)
M = 96        # Número de amostras
plan = NFFT(N, M)

# Define as coordenadas no domínio [-0.5, 0.5]^2
x = np.random.rand(M, 2) - 0.5  # Coordenadas bidimensionais
plan.x = x
plan.precompute()  # Pré-computação

# Define os dados no domínio da frequência (f_hat)
f_hat = np.random.rand(N[0], N[1]) + 1j * np.random.rand(N[0], N[1])  # Dados complexos
plan.f_hat = f_hat

# Transformada direta: f_hat -> f
f = plan.trafo()
print("Transformada Direta (f):", f)

# Transformada adjunta: f -> f_hat
plan.f = f
f_hat_reconstructed = plan.adjoint()
#print("Reconstrução Adjunta (f_hat):", f_hat_reconstructed)
# Out:
# Transformada Direta (f): [ 4.95310630e+00 -1.18632414j -3.70622397e+00 -5.37766553j
#  -2.31519194e+00 -6.17191647j -5.38276429e+00 +0.21407036j
#  -2.47689363e+00 -6.97198646j  3.74003352e+00 +2.34833055j
#   7.34882827e+01+63.25056143j -8.15103217e+00 +2.19977243j
#  -5.24185253e+00 -1.34936927j -1.00052589e+00 -0.33135162j
#   5.19367572e+00 +1.12258792j -1.50220656e+00 +0.98630346j
#   5.28444283e-01 +0.41963424j -1.11032426e-01 -2.77242586j
#   4.93647256e+00+12.09438924j  2.78299776e+00 -4.47741761j
#   3.39610489e+00 -0.97992232j  1.06263973e+01 -2.73168541j
#  -3.07813772e+00 -1.21226615j -3.86699792e+00 -2.36138125j
#   3.79740752e+00 +0.65742748j  6.50345717e+00 -0.38580523j
#   1.16056891e+01 +7.57911031j -3.69634359e-01 -1.34422542j
#  -5.17616539e+00 -4.45803512j -2.12512144e+00-14.94328543j
#   1.81637139e+00 -3.28212091j -4.24487012e-01 +1.79922276j
#   2.29310300e+00 -5.52593571j  4.05919665e+01+35.4906174j
#  -3.15743914e+00 -0.67817416j  6.65108465e+00 +6.05642363j
#   6.85717817e+00 +2.86458245j  6.36894912e+00 -8.39857914j
#  -4.07731513e+00 -0.94915986j -2.65041454e+00 +2.16072328j
#   4.92656899e+00 +0.50630892j  1.37859952e+00 -1.11838117j
#   6.99656826e+00 -8.94777991j -8.22990924e-01 -4.61897991j
#   2.74982521e+00 -4.28242011j  3.75028365e+00 +9.16923855j
#   2.15108158e+00 +7.04054577j  4.15083838e-01 +4.56980977j
#  -4.28739665e+00 -3.93090566j  6.74009564e+00 -6.35557607j
#  -1.26143342e+01 +3.73785507j  2.63636587e-01 +0.37128627j
#  -5.71571332e+00 -5.76690181j -6.47150608e+00 -0.34173147j
#  -8.05955247e+00 -4.8984408j   2.95274338e-01 +4.71980205j
#   1.50756194e+00 -0.68837277j -9.60168115e+00+16.83557882j
#         3.88663447e-033+5.20749682e-090j,
#         9.72380051e-072+1.21134165e-099j,
#         5.98149239e-154+4.04676249e-086j,
#         1.40074737e-076+3.65486975e-086j,
#         9.96535464e-043+1.15504345e-259j,
#         2.47379808e-091+2.42301668e-052j,
#         1.15643428e-100+2.00375949e-052j,
#         3.17217097e+203+6.01347002e-154j,
#         5.35540481e-038+1.39642642e-076j,
#         1.83154373e-076+1.39710108e-076j,
#         6.01346953e-154+1.31196884e-071j,
#         1.21089779e-099+3.69285922e-057j,
#         1.21268195e-099+5.98149239e-154j,
#         4.04676249e-086+7.40219310e-038j,
#         3.85437531e-086+4.46664401e-033j,
#         1.15504345e-259+2.47379808e-091j,
#         5.93394608e-038+4.96684742e-091j,
#         1.51978956e-047+3.17217097e+203j,
#         6.01347002e-154+1.08668061e-071j,
#         1.39642639e-076+1.08621512e-042j,
#         1.39642640e-076+6.01346953e-154j,
#         8.59810764e-067+1.21178989e-099j,
#         2.57771190e-057+1.21089429e-099j,
#         5.98149239e-154+4.64999190e-086j,
#         4.66452378e-033+3.45379329e-086j])

# %%
import numpy as np
import matplotlib.pyplot as plt
from pynfft.nfft import NFFT

# Configuração dos parâmetros
N = [16, 16]  # Domínio da frequência (2D)
M = 96        # Número de amostras
plan = NFFT(N, M)

# Coordenadas no domínio [-0.5, 0.5]^2
x = np.random.rand(M, 2) - 0.5  # Coordenadas bidimensionais
plan.x = x
plan.precompute()  # Pré-computação

# Plotando o espaço amostral
plt.figure(figsize=(6, 6))
plt.scatter(x[:, 0], x[:, 1], color='blue', label='Amostras')
plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')
plt.xlim([-0.5, 0.5])
plt.ylim([-0.5, 0.5])
plt.title("Espaço Amostral 2D")
plt.xlabel("Coordenada x")
plt.ylabel("Coordenada y")
plt.legend()
plt.grid()
plt.show()

# %%
# Gerando valores associados (complexos)
f = np.random.rand(M) + 1j * np.random.rand(M)

# Magnitude dos valores para visualização
magnitude = np.abs(f)

# Plotando as magnitudes no espaço amostral
plt.figure(figsize=(6, 6))
plt.scatter(x[:, 0], x[:, 1], c=magnitude, cmap='viridis', label='Magnitude')
plt.colorbar(label="Magnitude de f")
plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')
plt.xlim([-0.5, 0.5])
plt.ylim([-0.5, 0.5])
plt.title("Valores Associados às Amostras")
plt.xlabel("Coordenada x")
plt.ylabel("Coordenada y")
plt.legend()
plt.grid()
plt.show()

# %%
# Dados no domínio da frequência
f_hat = np.random.rand(N[0], N[1]) + 1j * np.random.rand(N[0], N[1])
plan.f_hat = f_hat

# Transformada direta
f = plan.trafo()

# Magnitude no domínio da frequência
freq_magnitude = np.abs(f_hat)

# Grid de frequências
kx = np.arange(N[0])
ky = np.arange(N[1])
kx, ky = np.meshgrid(kx, ky)

# Plotando o espaço da frequência
plt.figure(figsize=(6, 6))
plt.pcolormesh(kx, ky, freq_magnitude, shading='auto', cmap='viridis')
plt.colorbar(label="Magnitude de F")
plt.title("Espaço da Frequência")
plt.xlabel("Frequência kx")
plt.ylabel("Frequência ky")
plt.grid()
plt.show()
